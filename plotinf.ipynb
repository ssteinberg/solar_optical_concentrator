# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import matplotlib
from pathlib import Path

from util import get_target_type_name

matplotlib.rc('figure', figsize = (10, 5))

# %%
target_type, elliptical_target_x_radius, elliptical_target_y_radius, inv, L, f, dB, B_max, aperture_size = np.loadtxt('datainf/input.csv', delimiter = ',')
data_mean_paths = np.loadtxt('datainf/mean.csv', delimiter = ',')
mirror1a = np.loadtxt('datainf/mirror1a.csv', delimiter = ',')
mirror1b = np.loadtxt('datainf/mirror1b.csv', delimiter = ',')
mirror2a = np.loadtxt('datainf/mirror2a.csv', delimiter = ',')
mirror2b = np.loadtxt('datainf/mirror2b.csv', delimiter = ',')

inverted_text = "inverted" if inv else "not inverted"
print(f"infinite system, {get_target_type_name(target_type)} target, {inverted_text}, L = {L}, f = {f}, dB = {dB :.6f}, B_max = {B_max}, aperture_size = {aperture_size}")

fig, ax = plt.subplots()

match int(target_type):
    case 0:
        plt.plot([0, 0], [-0.005, 0.005], c = 'red')
    case 1:
        circle = plt.Circle((0, 0), 0.005, color = 'red')
        ax.add_patch(circle)
    case 2:
        ellipse = Ellipse(
            xy=(0, 0),
            width=2*elliptical_target_x_radius,
            height=2*elliptical_target_y_radius,
            angle=0,
            linewidth=0.1,
            color = 'red'
        )
        ax.add_patch(ellipse)

plt.plot(mirror1a[:, 0], mirror1a[:, 1], linewidth = 1, c = 'blue', label = 'mirror 1a')
plt.plot(mirror1b[:, 0], mirror1b[:, 1], linewidth = 1, c = 'blue', label = 'mirror 1b')
plt.plot(mirror2a[:, 0], mirror2a[:, 1], linewidth = 1, c = 'purple', label = 'mirror 2a')
plt.plot(mirror2b[:, 0], mirror2b[:, 1], linewidth = 1, c = 'purple', label = 'mirror 2b')

for i, row in enumerate(data_mean_paths):
    X = [row[0], row[2]]
    Y = [row[1], row[3]]
    # colour = plt.cm.hsv((i//3) / len(data_mean_paths))
    colour = 'grey'
    plt.plot(X, Y, color=colour, linewidth = 0.1)

# plt.axis('equal')
ax.axis('off')
ax.set_xlim(-80, 15)
ax.set_ylim(-50, 50)
ax.set_aspect('equal', adjustable='box')
# plt.axis((-13, 8, -10, 10))
# plt.legend()
# plt.title(f"x radius = {elliptical_target_x_radius}, y radius = {elliptical_target_y_radius}")
plt.show()
from pathlib import Path
Path("results").mkdir(parents=True, exist_ok=True)
fig.savefig(f"results/x-{elliptical_target_x_radius}-y-{elliptical_target_y_radius}.png", bbox_inches="tight", pad_inches=0, dpi=1000)
# Out:
# infinite system, Elliptical target, inverted, L = 64.0, f = 4.0, dB = 0.000010, B_max = 150.0, aperture_size = 30.0

# %%
extr1 = np.loadtxt('datainf/extrinf1.csv', delimiter = ',')
extr2 = np.loadtxt('datainf/extrinf2.csv', delimiter = ',')

zoom_x = 0.02
zoom_y = 0.02
fig, ax = plt.subplots()

match int(target_type):
    case 0:
        plt.plot([0, 0], [-0.005, 0.005], c = 'orange')
    case 1:
        circle = plt.Circle((0, 0), 0.005, color = 'orange')
        ax.add_patch(circle)
    case 2:
        ellipse = Ellipse(
            xy=(0, 0),
            width=2*elliptical_target_x_radius,
            height=2*elliptical_target_y_radius,
            angle=0,
            color = 'black'
        )
        ax.add_patch(ellipse)
        zoom_x = max(0.02, ellipse.width * 2)
        zoom_y = max(0.02, ellipse.height * 2)

plt.plot(mirror1a[:, 0], mirror1a[:, 1], linewidth = 1, c = 'blue', label = 'mirror 1a')
plt.plot(mirror1b[:, 0], mirror1b[:, 1], linewidth = 1, c = 'cornflowerblue', label = 'mirror 1b')
plt.plot(mirror2a[:, 0], mirror2a[:, 1], linewidth = 1, c = 'purple', label = 'mirror 2a')
plt.plot(mirror2b[:, 0], mirror2b[:, 1], linewidth = 1, c = 'mediumpurple', label = 'mirror 2b')

for row in extr1: plt.plot([row[0], row[2]], [row[1], row[3]], linewidth = 0.2, c = 'blue')
for row in extr2: plt.plot([row[0], row[2]], [row[1], row[3]], linewidth = 0.2, c = 'red')

# plt.axis('equal')
plt.axis('square')
plt.axis((-zoom_x, zoom_x, -zoom_y, zoom_y))
plt.show()

# %% [markdown]
# # Two-Mirror Concentrator

# %%
# import
# data_2mc = np.loadtxt('data_2mc_flat.csv', delimiter = ',')
# data_2mc = np.loadtxt('data_2mc_cyl.csv', delimiter = ',')
data_2mc = np.loadtxt('data_2mc_fin_cyl.csv', delimiter = ',')

# parameters
f1, L, f2 = 2, 10, 1

# source and target
plt.scatter(-L, 0, s = 5, c = 'orange', label = 'source')
plt.scatter(0, 0, s = 5, c = 'red', label = 'target')

# M1
plt.plot(data_2mc[:, 0], data_2mc[:, 1], linewidth = 1, c = 'purple', label = 'M1')
# plt.text(data_2mc[0, 0], data_2mc[0, 1], s = f'({data_2mc[0, 0]}, {data_2mc[0, 1]})')
# plt.text(data_2mc[data_2mc.shape[0] - 1, 0], data_2mc[data_2mc.shape[0] - 1, 1], s = f'({data_2mc[data_2mc.shape[0] - 1, 0]}, {data_2mc[data_2mc.shape[0] - 1, 1]})')

# M2
plt.plot(data_2mc[:, 2], data_2mc[:, 3], linewidth = 1, c = 'blue', label = 'M2')
# plt.text(data_2mc[0, 2], data_2mc[0, 3], s = f'({data_2mc[0, 2]}, {data_2mc[0, 3]})')
# plt.text(data_2mc[data_2mc.shape[0] - 1, 2], data_2mc[data_2mc.shape[0] - 1, 3], s = f'({data_2mc[data_2mc.shape[0] - 1, 2]}, {data_2mc[data_2mc.shape[0] - 1, 3]})')

# parabola
M1Y = np.linspace(data_2mc[0, 1], data_2mc[-1, 1], 50)
M1X = 1 / (4 * f1) * (M1Y ** 2) - L - f1
plt.scatter(M1X, M1Y, s = 5, c = 'purple', label = 'PM1')
M2Y = np.linspace(data_2mc[0, 3], data_2mc[-1, 3], 50)
M2X = -1 / (4 * f2) * (M2Y ** 2) + f2
plt.scatter(M2X, M2Y, s = 5, c = 'blue', label = 'PM2')

# display
plt.axis('equal')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[118], line 4
#       1 # import
#       2 # data_2mc = np.loadtxt('data_2mc_flat.csv', delimiter = ',')
#       3 # data_2mc = np.loadtxt('data_2mc_cyl.csv', delimiter = ',')
# ----> 4 data_2mc = np.loadtxt('data_2mc_fin_cyl.csv', delimiter = ',')
#       6 # parameters
#       7 f1, L, f2 = 2, 10, 1
#
# File c:\Users\Iman\Documents\Programming\Courses\URA_Winter_2026\solar_optical_concentrator\venv\Lib\site-packages\numpy\lib\_npyio_impl.py:1384, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1381 if isinstance(delimiter, bytes):
#    1382     delimiter = delimiter.decode('latin1')
# -> 1384 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %% [markdown]
# # Concentration of mean rays

# %%
# import
# data_mean_paths = np.loadtxt('data_2mc_flat_mean.csv', delimiter = ',')
data_mean_paths = np.loadtxt('data_2mc_cyl_mean.csv', delimiter = ',')

# zoom
plt.axis('square')
zoom = 0.001
plt.axis([-zoom, zoom, -zoom, zoom])

# circle
circle = plt.Circle((0, 0), zoom, color = 'black')
plt.gca().add_patch(circle)

# mean ray paths
for row in data_mean_paths:
    # X = [x for j, x in enumerate(row) if j % 2 == 0]
	# Y = [y for j, y in enumerate(row) if j % 2 == 1]
    X = [row[4], row[6]]
    Y = [row[5], row[7]]
    plt.plot(X, Y, 'g', linewidth = 0.25)

# display
plt.show()

# %% [markdown]
# # Concentration of extreme rays

# %%
# import
# data_pos_extr_paths = np.loadtxt('data_2mc_flat_extr_pos.csv', delimiter = ',')
# data_neg_extr_paths = np.loadtxt('data_2mc_flat_extr_neg.csv', delimiter = ',')
# data_pos_extr_paths = np.loadtxt('data_2mc_cyl_extr_pos.csv', delimiter = ',')
# data_neg_extr_paths = np.loadtxt('data_2mc_cyl_extr_neg.csv', delimiter = ',')

# zoom
plt.axis('square')
zoom = 0.01
plt.axis([-zoom, zoom, -zoom, zoom])

# circle
circle = plt.Circle((0, 0), zoom / 2.1, color = 'black')
plt.gca().add_patch(circle)

# extreme ray paths
# for row in data_pos_extr_paths:
#     X = [row[4], row[6]]
#     Y = [row[5], row[7]]
#     plt.plot(X, Y, 'r', linewidth = 0.25)
# for row in data_neg_extr_paths:
#     X = [row[4], row[6]]
#     Y = [row[5], row[7]]
#     plt.plot(X, Y, 'b', linewidth = 0.25)

# display
plt.show()

# %% [markdown]
# # Parabolic Mirror

# %%
# data_pm = np.loadtxt('build/data_pm.csv', delimiter = ',')
# data_pm_a = np.loadtxt('build/data_pm_a.csv', delimiter = ',')
# data_pm_b = np.loadtxt('build/data_pm_b.csv', delimiter = ',')
# data_pm_c = np.loadtxt('build/data_pm_c.csv', delimiter = ',')

# %%
# plt.scatter(0, 0, c = 'black')
# plt.plot(data_pm[:, 0], data_pm[:, 1], linewidth = 2, c = 'm')

# for row in data_pm_a: plt.plot([row[2], row[4]], [row[3], row[5]], 'g', linewidth = 0.25)
# for row in data_pm_b: plt.plot([row[2], row[4]], [row[3], row[5]], 'r', linewidth = 0.25)
# for row in data_pm_c: plt.plot([row[2], row[4]], [row[3], row[5]], 'b', linewidth = 0.25)

# plt.axis('square')
# zoom = 0.005
# plt.axis([-zoom, zoom, -zoom, zoom])
# plt.show()
